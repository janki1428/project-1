# %%
# import dependencies
import pandas as pd

# %%
# read in csv file ('tayler_swift_spotify.csv') from same folder
tswift_data = pd.read_csv("taylor_swift_spotify.csv")

# display the first few rows to see what the data looks like
tswift_data.head()
# Out:
#    Unnamed: 0                                 name  \
# 0           0              Mine (Taylor's Version)
# 1           1        Sparks Fly (Taylor’s Version)
# 2           2  Back To December (Taylor's Version)
# 3           3         Speak Now (Taylor's Version)
# 4           4         Dear John (Taylor's Version)
#
#                           album release_date  track_number  \
# 0  Speak Now (Taylor's Version)   2023-07-07             1
# 1  Speak Now (Taylor's Version)   2023-07-07             2
# 2  Speak Now (Taylor's Version)   2023-07-07             3
# 3  Speak Now (Taylor's Version)   2023-07-07             4
# 4  Speak Now (Taylor's Version)   2023-07-07             5
#
#                        id                                   uri  acousticness  \
# 0  7G0gBu6nLdhFDPRLc0HdDG  spotify:track:7G0gBu6nLdhFDPRLc0HdDG       0.00444
# 1  3MytWN8L7shNYzGl4tAKRp  spotify:track:3MytWN8L7shNYzGl4tAKRp       0.02510
# 2  79uDOz0zuuWS7HWxzMmTa2  spotify:track:79uDOz0zuuWS7HWxzMmTa2       0.00621
# 3  5xXqyjLicvEpch72qEryFT  spotify:track:5xXqyjLicvEpch72qEryFT       0.24800
# 4  1zU8j1x3yi9xalMF96pzKp  spotify:track:1zU8j1x3yi9xalMF96pzKp       0.02360
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.646   0.783          0.000001     0.171    -2.846       0.0356
# 1         0.588   0.758          0.000000     0.131    -2.347       0.0305
# 2         0.497   0.635          0.000000     0.117    -3.927       0.0273
# 3         0.727   0.677          0.000000     0.143    -2.871       0.0325
# 4         0.419   0.470          0.000000     0.163    -5.016       0.0296
#
#      tempo  valence  popularity  duration_ms
# 0  121.080    0.490          83       231706
# 1  114.991    0.387          81       261230
# 2  142.063    0.203          84       294189
# 3  118.995    0.639          80       242473
# 4  119.294    0.133          80       405906

# %%
# how many rows are there in the dataset (each row has a unique song id)
# we will use this in a moment to check how many duplicates there were
tswift_data['id'].count()
# Out:
# 476

# %%
# remove columns which we don't need, uri and the unnamed column
swift_reduced = tswift_data[['name', 'album', 'release_date', 'id', 'acousticness', 'danceability', 'energy', 
                             'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'popularity',
                             'duration_ms']]

# drop columns which are duplicates in name and every numerical column (they are true duplicates, in that sense)
swift_df = swift_reduced.drop_duplicates(subset=['name', 'acousticness', 'danceability', 'energy', 'instrumentalness', 
                                                 'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'duration_ms'])

# check that there are fewer rows, how many duplicates were removed
# original count for unique ids was 476
# after the duplicates are removed there are 420 rows, so 56 duplicates were removed

# swift_df is the dataframe we should all use for our analysis, has no duplicate rows and no unneeded columns
swift_df
# Out:
#                                      name                         album  \
# 0                 Mine (Taylor's Version)  Speak Now (Taylor's Version)
# 1           Sparks Fly (Taylor’s Version)  Speak Now (Taylor's Version)
# 2     Back To December (Taylor's Version)  Speak Now (Taylor's Version)
# 3            Speak Now (Taylor's Version)  Speak Now (Taylor's Version)
# 4            Dear John (Taylor's Version)  Speak Now (Taylor's Version)
# ..                                    ...                           ...
# 471                              Our Song                  Taylor Swift
# 472         I'm Only Me When I'm With You                  Taylor Swift
# 473                             Invisible                  Taylor Swift
# 474                A Perfectly Good Heart                  Taylor Swift
# 475  Teardrops on My Guitar - Pop Version                  Taylor Swift
#
#     release_date                      id  acousticness  danceability  energy  \
# 0     2023-07-07  7G0gBu6nLdhFDPRLc0HdDG       0.00444         0.646   0.783
# 1     2023-07-07  3MytWN8L7shNYzGl4tAKRp       0.02510         0.588   0.758
# 2     2023-07-07  79uDOz0zuuWS7HWxzMmTa2       0.00621         0.497   0.635
# 3     2023-07-07  5xXqyjLicvEpch72qEryFT       0.24800         0.727   0.677
# 4     2023-07-07  1zU8j1x3yi9xalMF96pzKp       0.02360         0.419   0.470
# ..           ...                     ...           ...           ...     ...
# 471   2006-10-24  1j6gmK6u4WNI33lMZ8dC1s       0.11100         0.668   0.672
# 472   2006-10-24  7CzxXgQXurKZCyHz9ufbo1       0.00452         0.563   0.934
# 473   2006-10-24  1k3PzDNjg38cWqOvL4M9vq       0.63700         0.612   0.394
# 474   2006-10-24  0YgHuReCSPwTXYny7isLja       0.00349         0.483   0.751
# 475   2006-10-24  1hxLyjC9D9Jpw6EAPKqWv4       0.04020         0.459   0.753
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0            0.000001    0.1710    -2.846       0.0356  121.080    0.490
# 1            0.000000    0.1310    -2.347       0.0305  114.991    0.387
# 2            0.000000    0.1170    -3.927       0.0273  142.063    0.203
# 3            0.000000    0.1430    -2.871       0.0325  118.995    0.639
# 4            0.000000    0.1630    -5.016       0.0296  119.294    0.133
# ..                ...       ...       ...          ...      ...      ...
# 471          0.000000    0.3290    -4.931       0.0303   89.011    0.539
# 472          0.000807    0.1030    -3.629       0.0646  143.964    0.518
# 473          0.000000    0.1470    -5.723       0.0243   96.001    0.233
# 474          0.000000    0.1280    -5.726       0.0365  156.092    0.268
# 475          0.000000    0.0863    -3.827       0.0537  199.997    0.483
#
#      popularity  duration_ms
# 0            83       231706
# 1            81       261230
# 2            84       294189
# 3            80       242473
# 4            80       405906
# ..          ...          ...
# 471          69       201106
# 472          59       213053
# 473          57       203226
# 474          56       220146
# 475          56       179066
#
# [420 rows x 15 columns]

# %%
# now export swift_df to a new csv as the cleaned dataset
swift_df.to_csv('swift_spotify_clean.csv')
